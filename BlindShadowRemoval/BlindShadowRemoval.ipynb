# %%
# !git clone https://github.com/Linchenchen/BlindShadowRemoval.git
# Out:
# Cloning into 'BlindShadowRemoval'...
# remote: Enumerating objects: 1242, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 1242 (delta 35), reused 51 (delta 15), pack-reused 1154
# Receiving objects: 100% (1242/1242), 171.88 MiB | 16.28 MiB/s, done.
# Resolving deltas: 100% (208/208), done.
# Updating files: 100% (1237/1237), done.

# %%
cd BlindShadowRemoval
# Out:
# /content/BlindShadowRemoval

# %%
# !pip install tensorflow==2.13.0
# !pip install tensorflow-addons==0.21.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 6.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tensorflow-addons
#     Found existing installation: tensorflow-addons 0.23.0
#     Uninstalling tensorflow-addons-0.23.0:
#       Successfully uninstalled tensorflow-addons-0.23.0
# ...

# %%
import tensorflow as tf
print("Tensorflow version: ", tf.version.VERSION)
# Out:
# Tensorflow version:  2.11.0

# %% [markdown]
# ### Install TensorRT Runtime

# %%
# !pip install tensorrt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tensorrt: filename=tensorrt-8.6.1.post1-py2.py3-none-any.whl size=17283 sha256=ef48e97f39e34da9161293e96f878cfbdb62ff601135f01a7aca2521bd932d9b
#   Stored in directory: /root/.cache/pip/wheels/f4/c8/0e/b79b08e45752491b9acfdbd69e8a609e8b2ed7640dda5a3e59
# Successfully built tensorrt
# ...

# %% [markdown]
# ### Check Tensor core GPU
# The below code check whether a Tensor-core GPU is present.

# %%
from tensorflow.python.client import device_lib

def check_tensor_core_gpu_present():
    local_device_protos = device_lib.list_local_devices()
    for line in local_device_protos:
        if "compute capability" in str(line):
            compute_capability = float(line.physical_device_desc.split("compute capability: ")[-1])
            if compute_capability>=7.0:
                return True

print("Tensor Core GPU Present:", check_tensor_core_gpu_present())
tensor_core_gpu = check_tensor_core_gpu_present()
# Out:
# Tensor Core GPU Present: True

# %%
# !python train_test_GSC.py --gpu_id 0
# Out:
# 2023-12-04 04:40:46.477388: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-04 04:40:47.518638: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# ...

# %%
# !zip -r /content/result.zip /content/BlindShadowRemoval/log/FSR-OG-perlin-mask-OG-loss-weights-l1-recon-fix-BGR-to-RGB-fix-VGG-greater-augmentation-reweight-gradients/test
# Out:
#   adding: content/BlindShadowRemoval/log/FSR-OG-perlin-mask-OG-loss-weights-l1-recon-fix-BGR-to-RGB-fix-VGG-greater-augmentation-reweight-gradients/test/ (stored 0%)
#   adding: content/BlindShadowRemoval/log/FSR-OG-perlin-mask-OG-loss-weights-l1-recon-fix-BGR-to-RGB-fix-VGG-greater-augmentation-reweight-gradients/test/9162_9162-025-result.png (deflated 4%)
#   adding: content/BlindShadowRemoval/log/FSR-OG-perlin-mask-OG-loss-weights-l1-recon-fix-BGR-to-RGB-fix-VGG-greater-augmentation-reweight-gradients/test/9190_9190-007-result.png (deflated 4%)
#   adding: content/BlindShadowRemoval/log/FSR-OG-perlin-mask-OG-loss-weights-l1-recon-fix-BGR-to-RGB-fix-VGG-greater-augmentation-reweight-gradients/test/9189_9189-002-result.png (deflated 4%)
#   adding: content/BlindShadowRemoval/log/FSR-OG-perlin-mask-OG-loss-weights-l1-recon-fix-BGR-to-RGB-fix-VGG-greater-augmentation-reweight-gradients/test/9180_9180-008-result.png (deflated 5%)
# ...
